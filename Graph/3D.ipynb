# %%
# %pip install numpy
# %pip install matplotlib
# %pip install alt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Cria uma figura e um eixo 3D
fig = plt.figure(figsize=(9, 6))
ex = fig.add_subplot(111, projection='3d')  # Adiciona um subplot 3D

# Define os intervalos para x e y
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

# Cria uma malha de coordenadas X e Y
X, Y = np.meshgrid(x, y)

# Calcula Z (função matemática)
Z = np.sin(np.sqrt(-(Y + 47.0) * np.sin(np.sqrt(abs(X/2.0 + (Y + 47.0)))) - X * np.sin(np.sqrt(abs(X - (Y + 47.0))))))

# Plota a superfície 3D
ex.plot_surface(X, Y, Z, cmap='inferno')

# Define os rótulos dos eixos
ex.set_xlabel('x')
ex.set_ylabel('y')
ex.set_zlabel('z')

# Exibe o gráfico
plt.show()
# Out:
# C:\Users\jaysa.sousa\AppData\Local\Temp\ipykernel_16416\4107708835.py:17: RuntimeWarning: invalid value encountered in sqrt
#   Z = np.sin(np.sqrt(-(Y + 47.0) * np.sin(np.sqrt(abs(X/2.0 + (Y + 47.0)))) - X * np.sin(np.sqrt(abs(X - (Y + 47.0))))))

# %%
import numpy as np

def sphere(x):
  d=x.share[0]
  sum=0
  for i in range(d):
    sum=sum+x[i]**2
  return sum

x = np.linspace(-5.12, 5.12, 4)
y = np.linspace(-5.12, 5.12, 4)

x, y = np.linspace(x, y)
#x=[x1, x2]
z = sphere([xi,x2])

plt.plot(z, f(x))
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 13
#      10 x = np.linspace(-5.12, 5.12, 4)
#      11 y = np.linspace(-5.12, 5.12, 4)
# ---> 13 x, y = np.linspace(x, y)
#      14 #x=[x1, x2]
#      15 z = sphere([xi,x2])
#
# ValueError: too many values to unpack (expected 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def f(x):
  return np.exp(-x)-x

a=0
b=1
x=np.arrange(a,b,0.1)
xo=0.5

plt.plot(x,f(x))
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 10
#       8 a=0
#       9 b=1
# ---> 10 x=np.arrange(a,b,0.1)
#      11 xo=0.5
#      13 plt.plot(x,f(x))
#
# File c:\Users\jaysa.sousa\AppData\Local\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

fig = plt.figure()
ax = Axes3D(fig)

x = [6,3,6,9,12,24]
y = [3,5,78,12,23,56]

ax.plot(x, y, zs=0, zdir='z', label='zs=0, zdir=z')

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# Criando a figura e projeção em 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Utilizando dados de teste
X, Y, Z = axes3d.get_test_data(0.10)

# Criando um Plot básico
ax.plot_wireframe(X, Y, Z, rstride=15, cstride=15)

# Exibindo o gráfico criado
plt.show()

# %%
#1. Exemplo Básico Gráfico 3D Wireframe Plot

#2. Exemplo Gráfico Filled Contours

# Importando as bibliotecas necessárias
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

# Criando a figura e projeção em 3D
fig = plt.figure()
ax = fig.gca(projection='3d')

# Utilizando dados de teste
X, Y, Z = axes3d.get_test_data(0.05)

# Criando o gráfico com extend3d
cset = ax.contour(X, Y, Z, extend3d=True, cmap=cm.seismic)

# Exibindo o gráfico criado
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 12
#      10 # Criando a figura e projeção em 3D
#      11 fig = plt.figure()
# ---> 12 ax = fig.gca(projection='3d')
#      14 # Utilizando dados de teste
#      15 X, Y, Z = axes3d.get_test_data(0.05)
#
# TypeError: FigureBase.gca() got an unexpected keyword argument 'projection'

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

# Criando a figura e projeção em 3D
fig = plt.figure()
ax = fig.gca(projection='3d')

# Utilizando dados de teste
X, Y, Z = axes3d.get_test_data(0.15)

# Criando o gráfico
cset = ax.contourf(X, Y, Z, cmap=cm.coolwarm)

# Exibindo o gráfico criado
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       5 # Criando a figura e projeção em 3D
#       6 fig = plt.figure()
# ----> 7 ax = fig.gca(projection='3d')
#       9 # Utilizando dados de teste
#      10 X, Y, Z = axes3d.get_test_data(0.15)
#
# TypeError: FigureBase.gca() got an unexpected keyword argument 'projection'

# %%
#test 08
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)

x, y = np.meshgrid(x, y)
z = np.sin(x) + 2*np.cos(y)

fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection = '3d')
ax.contour3D(x, y, z, 100, cmap = 'viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.savefig('3d contour.png', dpi = 300)

# %%
#test 04
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plot
import numpy as np
# create data points
x = np.linspace(-10, 10, 100)
y = np.linspace(-15, 15, 100)
# create grid
X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)
# create figure container
fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection = '3d')
# 3d contour plot
ax.contour3D(X, Y, Z, 100, cmap = 'viridis')
# set labels
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plot
import numpy as np
# create data points
x = np.linspace(-10, 10, 100)
y = np.linspace(-15, 15, 100)
# create grid
X, Y = np.meshgrid(x, y)

#termo1 = -(Y + 47.0) * np.sin(np.sqrt(abs(X/2.0 + (Y + 47.0))))
#termo2 = - X * np.sin(np.sqrt(abs(X - (Y + 47.0))))
#Z = termo1 + termno2

Z = -(Y + 47.0) * np.sin(np.sqrt(abs(X/2.0 + (Y + 47.0)))) - X * np.sin(np.sqrt(abs(X - (Y + 47.0))))
# create figure container
fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection = '3d')
# 3d contour plot
ax.contour3D(X, Y, Z, 100, cmap = 'viridis')
# set labels
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %%
#test 03
def rosenbrock(x,y):
      return (1-x)*2 + 100 ((y-x*2))*2


from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plot
import numpy as np

fig = plot.figure()
ax = fig.gca(projection='3d')

s = 0.05   # Try s=1, 0.25, 0.1, or 0.05
X = np.arange(-2, 2.+s, s)   #Could use linspace instead if dividing
Y = np.arange(-2, 3.+s, s)   #evenly instead of stepping...

#Create the mesh grid(s) for all X/Y combos.
X, Y = np.meshgrid(X, Y)

#Rosenbrock function w/ two parameters using numpy Arrays
Z = (1*-X)*2 + 100*(Y-X*X)**2

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
         linewidth=0, antialiased=False)  #Try coolwarm vs jet


ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

#Displays the figure, handles user interface, returns when user closes window
plot.show()

# %%
def sodp(x):
    d=len(x)
    sum=0
    xi = [x1, x2]
    for i in range(d):
        sum+= np.abs(x[i-1])**(i+1)
    return sum
# create data points
x1 = np.linspace(-1, 1, 100)
x2 = np.linspace(-1, 1, 100)
xi = [x1, x2]
# create grid
X1, X2 = np.meshgrid(x1, x2)
Z = sodp([X1,X2])
# create figure container
fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection = '3d')
# 3d contour plot
ax.contour3D(X1, X2, Z, 100, cmap = 'viridis')
# set labels
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('z')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plot
import numpy as np
# create data points
x = np.linspace(-10, 10, 100)
y = np.linspace(-15, 15, 100)
# create grid
x, y = np.meshgrid(x, y)
Z = -(y + 47.0) * np.sin(np.sqrt(abs(x/2.0 + (y + 47.0)))) - x * np.sin(np.sqrt(abs(x - (y + 47.0))))
#(-(X[1] + 47) * np.sin(np.sqrt(abs(X[0]/2 + (X[1] + 47)))) -X[0] * np.sin(np.sqrt(abs(X[0] - (X[1] + 47)))))
# create figure container
fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection = '3d')
# 3d contour plot
ax.contour3D(X, Y, Z, 100, cmap = 'viridis')
# set labels
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

def rastrigin(x):
  d=x.shape[0]
  sum=0
  for i in range(d):
    sum=sum+x[i]**2-10*np.cos(2*np.pi*x[i])
  return 10*d+sum
x1 = np.linspace(-5.12, 5.12, 100)
x2 = np.linspace(-5.12, 5.12, 100)
x1, x2 = np.meshgrid(x1, x2)

l=[x1,x2]
arr = np.array(l)

z = rastrigin(arr)

fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(x1, x2, z, rstride=8, cstride=8, alpha=0.8,cmap=cm.viridis)
cset = ax.contourf(x1, x2, z, zdir='z', offset=np.min(Z), cmap=cm.ocean)

fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

ax.set_xlabel('x')
ax.set_xlim(-5, 5)
ax.set_ylabel('y')
ax.set_ylim(-5, 5)
ax.set_zlabel('z')
ax.set_zlim(np.min(z), np.max(z))
ax.set_title('3D surface with 2D contour plot projections')

ax.view_init(30, -120)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
x, y = np.meshgrid(x, y)
term1 = (y+47) * np.sin(np.sqrt(abs(y+x/2+47)))
term2 = y * np.sin(np.sqrt(abs(x-(y+47))))
#z = (-(y + 47.0) * np.sin(np.sqrt(abs(x/2.0 + (y + 47.0)))) - x * np.sin(np.sqrt(abs(x - (y + 47.0)))))

z = term1 - term2

fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection = '3d')
ax.contour3D(x, y, z, 100, cmap = 'viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.savefig('3d contour.png', dpi = 300)

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import optimize
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,10))
axes = fig.gca(projection='3d')

def f(x, y):
    return (np.exp(np.sqrt(x**2 + y**2)))

y = x = np.linspace(-3, 3, 50)

x, y = np.meshgrid(x, y)
z = f(x,y)

# optimization
optimize.minimize(f, -3, args=(3)) # maybe something is wrong right here
optimization = optimize.minimize(f, -3, args=(3))


surf = axes.plot_surface(x, y, z, cmap='coolwarm',linewidth=0, antialiased=False)

surf1 = axes.plot_surface(x, y, f(optimization.x,y), cmap='coolwarm',linewidth=0, antialiased=False)

axes.set_xlabel('Ось X')
axes.set_ylabel('Ось Y')
axes.set_zlabel('Ось Z')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.linspace(-10, 10)
x2 = x1
x1, x2 = np.meshgrid(x1, x2)

termo1 = 0.26(X**2 + Y**2
termo2 = -0.48*X*Y

z= termo1 + termo2
fig= plt.figure(figsize=(9, 6))
ax = plt.axes(projection= '3d')

ax.contour3D(x1, x2, z, 300, cmap= 'inferno')


ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(xi, x2)')
ax.set_title('função drop-wave 3D')
ax.view_init(45, 215)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.linspace(-10, 10)
x2 = x1
x1, x2 = np.meshgrid(x1, x2)

mano = -(x2 + 47.0) * np.sin(np.sqrt(abs(x1/2.0 + (x2 + 47.0))))
cara = - x1 * np.sin(np.sqrt(abs(x1 - (x2 + 47.0))))

z= mano + cara
fig= plt.figure(figsize=(9, 6))
ax = plt.axes(projection= '3d')

ax.contour3D(x1, x2, z, 300, cmap= 'inferno')

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(xi, x2)')
ax.set_title('função drop-wave 3D')
ax.view_init(45, 215)

plt.show()

# %%
def rosenbrock(x,y):
      return (1-x)*2 + 100 ((y-x*2))*2


from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plot
import numpy as np

fig = plot.figure()
ax = fig.gca(projection='3d')

s = 0.05   # Try s=1, 0.25, 0.1, or 0.05
X = np.arange(-2.2 , +s, s)   #Could use linspace instead if dividing
Y = np.arange(-2.3 , +s, s)   #evenly instead of stepping...

#Create the mesh grid(s) for all X/Y combos.
X, Y = np.meshgrid(X, Y)

#Rosenbrock function w/ two parameters using numpy Arrays
Z = (1.-X)*2 + 100*(Y-X*X)**2

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
         linewidth=0, antialiased=False)  #Try coolwarm vs jet


ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

#Displays the figure, handles user interface, returns when user closes window
plot.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def corno(x):
  return (np.sin(x[0]) * np.exp((1-np.cos(x[1]))**2)
  +np.cos(x[1]) * np.exp((1-np.sin(x[0]))**2)+(x[0]-x[1])**2)

x = np.arange(-512, 512)
y = np.arange(-512, 512)
xgrid, ygrid = np.meshgrid(x, y)
xy = np.stack([xgrid, ygrid])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(45, -45)
ax.plot_surface(xgrid, ygrid, corno(xy), cmap='inferno')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('corno(x, y)')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def eggholder(x):
  return (-(x[1] + 47) * np.sin(np.sqrt(abs(x[0]/2 + (x[1]  + 47))))
  -x[0] * np.sin(np.sqrt(abs(x[0] - (x[1]  + 47)))))

x = np.arange(-512, 512)
y = np.arange(-512, 512)
xgrid, ygrid = np.meshgrid(x, y)
xy = np.stack([xgrid, ygrid])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(45, -45)
ax.plot_surface(xgrid, ygrid, eggholder(xy), cmap='inferno')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('eggholder(x, y)')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter('{x:.02f}')
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
import numpy as np
from random import random,seed
import math

seed(1)

def sphere(x):
  d=x.shape[0]
  sum=0
  for i in range(d):
    sum=sum+x[i]**2
  return sum


def eggholder(x):
  return (-(x[1] + 47) * np.sin(np.sqrt(abs(x[0]/2 + (x[1]  + 47))))
  -x[0] * np.sin(np.sqrt(abs(x[0] - (x[1]  + 47)))))


x_max=8
x_min=-8

c1=2
c2=2
ini_v=0.5

maxiter = 50
w0 = 0.9
wf = 0.1
slope = (wf-w0)/maxiter
w=w0
max_v = 5

S=5
x=np.zeros((S,2))
v=np.zeros((S,2))
y=np.zeros((S,2))

part,dim=x.shape

f_ind=1e10*np.ones([part,1])
fx=np.zeros((part,1))

for i in range(part):
  for j in range(dim):
    x[i,j]=x_min + (x_max-x_min) * random()
    v[i,j]=ini_v
    y[i,j]=1e10
t=0
while t<maxiter:

  for i in range(part):
    fx[i,0]=sphere(x[i,:])
    if fx[i,0]<f_ind[i,0]:
      y[i,:]=x[i,:]
      f_ind[i,0]=fx[i,0]

bestfitness=np.amin(f_ind)
result = np.where(f_ind == np.amin(f_ind))
p=result[0]

ys=y[p,:]

for j in range(dim):
  for i in range(part):
    r1=random()
    r2=random()
    v[i,j]=w*v[i,j] + c1*r1*(y[i,j]-x[i,j]) + c2*r2*(ys[0,j]-x[i,j])

    if math.fabs(v[i,j])>max_v:
      if v[i,j]>0:
        v[i,j] = max_v
      else:
        v[i,j] = -max_v
    x[i,j]=x[i,j] + v[i,j]

w=w+slope
t=t+1

print("minimo global=> {:.5f}".format(sphere(ys[0,:])))
print("resolução x1=> {:.5f} x2=> {:.5f}".format(ys[0,0],ys[0,1]))
